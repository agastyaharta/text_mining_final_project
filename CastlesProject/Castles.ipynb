# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import nltk
from sklearn.metrics import confusion_matrix, classification_report
import string
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.util import bigrams
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('vader_lexicon')
import seaborn as sns
import matplotlib.pyplot as plt
from afinn import Afinn
from collections import Counter
from itertools import tee
import warnings
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lukasz\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Lukasz\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Lukasz\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
warnings.filterwarnings('ignore')

# %%
castle_reviews = pd.read_csv("C:\\Users\\Lukasz\\Downloads\\castle_user_reviews.csv")
castle_details = pd.read_csv("C:\\Users\\Lukasz\\Downloads\\castle_details.csv")

# %%
castle_reviews
# Out:
#                     Name                Author  Rating  \
# 0      Hotel Grad Otočec         Ivet Sotirova       4
# 1      Hotel Grad Otočec    Gordana Podvezanec       5
# 2      Hotel Grad Otočec          Blaž Lusavec       5
# 3      Hotel Grad Otočec               Uros R.       5
# 4      Hotel Grad Otočec       Bogdan Tertinek       5
# ...                  ...                   ...     ...
# 2546  Oystermouth Castle             Kate Long       5
# 2547  Oystermouth Castle          Mia Thurgood       5
# 2548  Oystermouth Castle          Rohit Mishra       4
# 2549  Oystermouth Castle   Joseph Emman Pineda       4
# 2550  Oystermouth Castle  Miss Camille Bennett       5
#
#                                                  Review
# 0     More than a great and magical place. Clean, ta...
# 1     The Otočec castle, built on one of the islands...
# 2     Very tasty large cup of cappuccino and very go...
# 3     A beautiful castle to visit on an island on Kr...
# 4     This magnificent five-stars hotel hosts also a...
# ...                                                 ...
# 2546  Really interesting castle with a long and rich...
# 2547  Very nice castle, prices were good and family ...
# 2548  A perfect visit on a sunny day. It's a old cas...
# 2549  This is definitely worth a stop if you're visi...
# 2550  We didn't manage to go inside because it was s...
#
# [2551 rows x 4 columns]

# %%
castle_details
# Out:
#                                                   Name   Latitude  Longitude  \
# 0                                    Hotel Grad Otočec  45.838009  15.234847
# 1                                        Reszel Castle  54.048351  21.148280
# 2    Zamek w Krasiczynie | Hotel | Restauracja Rene...  49.776379  22.650112
# 3                                   Riegersburg Castle  47.004916  15.932297
# 4                                                 Kost  50.490204  15.135199
# ..                                                 ...        ...        ...
# 585                                   Restormel Castle  50.421576  -4.671019
# 586                                 Capela de São Brás  39.493942  -7.960963
# 587                                    Bamburgh Castle  55.608960  -1.709900
# 588                                   Park Or Dunamase  53.033874  -7.224758
# 589                                 Oystermouth Castle  51.576800  -4.002459
#
#     Adminstrative_Area_Level_1 Adminstrative_Area_Level_2  \
# 0                          NaN                        NaN
# 1                       Reszel          Powiat kętrzyński
# 2                    Krasiczyn           Powiat przemyski
# 3                  Riegersburg           Südoststeiermark
# 4                   Libošovice                      Jičín
# ..                         ...                        ...
# 585                        NaN                   Cornwall
# 586                        NaN                        NaN
# 587                        NaN             Northumberland
# 588                        NaN                        NaN
# 589                    Mumbles                    Swansea
#
#              Municipality         Country Postal_Code  \
# 0              Novo mesto        Slovenia        8222
# 1     Warmińsko-Mazurskie          Poland      11-440
# 2            Podkarpackie          Poland      37-741
# 3              Steiermark         Austria        8333
# 4    Královéhradecký kraj         Czechia       50601
# ..                    ...             ...         ...
# 585               England  United Kingdom     PL220EE
# 586   Portalegre District        Portugal        6040
# 587               England  United Kingdom     NE697DF
# 588          County Laois         Ireland         NaN
# 589                 Wales  United Kingdom      SA34BA
#
#                                       Address  \
# 0      Grajska cesta 2, 8222 Otočec, Slovenia
# 1          Podzamcze 3, 11-440 Reszel, Poland
# 2      Zamek, Zamek, 37-741 Krasiczyn, Poland
# 3    Riegersburg 1, 8333 Riegersburg, Austria
# 4       Podkost 1, 506 01 Libošovice, Czechia
# ..                                        ...
# 585    Restormel Rd, Lostwithiel PL22 0EE, UK
# 586                    Belver, 6040, Portugal
# 587                     Bamburgh NE69 7DF, UK
# 588      Park Or Dunamase, Co. Laois, Ireland
# 589  Castle Ave, Mumbles, Swansea SA3 4BA, UK
#
#                                      Editorial_Summary  \
# 0    Refined hotel in a medieval castle offering a ...
# 1    Regal hotel in a 15th-century castle offering ...
# 2    Relaxed quarters in a 17th-century castle hote...
# 3    Castle atop a dormant volcano featuring a witc...
# 4    14th-century fortress with tours of armory & t...
# ..                                                 ...
# 585  Romantic hilltop castle ruins for picnics, pan...
# 586                                                NaN
# 587  One-time seat of the Kings of Northumbria, wit...
# 588                                                NaN
# 589  Remains of a castle in use from 1106 to around...
#
#                                             Open_Hours  User_Rating  \
# 0                                                  NaN       1847.0
# 1    ['Monday: 0800 - 2200', 'Tuesday: 0800 - 2200'...       5054.0
# 2                                                  NaN       7691.0
# 3    ['Monday: 0900 - 1800', 'Tuesday: 0900 - 1800'...       4975.0
# 4    ['Monday: 0900 - 1800', 'Tuesday: 0900 - 1800'...       9225.0
# ..                                                 ...          ...
# 585  ['Monday: 1000 - 1700', 'Tuesday: 1000 - 1700'...        843.0
# 586                                                NaN          2.0
# 587  ['Monday: 1000 - 1700', 'Tuesday: 1000 - 1700'...      13251.0
# 588                                                NaN          NaN
# 589  ['Monday: 1100 - 1700', 'Tuesday: 1100 - 1700'...        956.0
#
#      Wheelchair_Accessible_Entrance    Phone_Number  \
# 0                              True  (07) 384 89 01
# 1                             False    89 755 01 09
# 2                              True    16 671 83 21
# 3                             False     03153 82131
# 4                             False     721 756 041
# ..                              ...             ...
# 585                            True    01208 872687
# 586                           False             NaN
# 587                            True    01668 214208
# 588                           False             NaN
# 589                            True             NaN
#
#     International_Phone_Number  \
# 0             +386 7 384 89 01
# 1             +48 89 755 01 09
# 2             +48 16 671 83 21
# 3               +43 3153 82131
# 4             +420 721 756 041
# ..                         ...
# 585            +44 1208 872687
# 586                        NaN
# 587            +44 1668 214208
# 588                        NaN
# 589                        NaN
#
#                                                Website
# 0                          http://www.grad-otocec.com/
# 1                         http://www.zamek-reszel.com/
# 2                         http://www.krasiczyn.com.pl/
# 3                       https://www.dieriegersburg.at/
# 4                             http://www.kost-hrad.cz/
# ..                                                 ...
# 585  http://www.english-heritage.org.uk/visit/place...
# 586                                                NaN
# 587                    https://www.bamburghcastle.com/
# 588                                                NaN
# 589            http://swansea.gov.uk/oystermouthcastle
#
# [590 rows x 16 columns]

# %%
castle_reviews['Rating'].value_counts()
# Out:
# Rating
# 5    1861
# 4     523
# 3      87
# 1      48
# 2      32
# Name: count, dtype: int64

# %%
castle_reviews['Sentiment'] = castle_reviews['Rating'].map({
    4: 'positive',
    5: 'positive',
    3: 'positive',
    1: 'negative',
    2: 'negative'
})

# %%
df_joined = pd.merge(
    castle_reviews,
    castle_details,
    on="Name",
    how="left")

# %%
df_joined
# Out:
#                     Name                Author  Rating  \
# 0      Hotel Grad Otočec         Ivet Sotirova       4
# 1      Hotel Grad Otočec    Gordana Podvezanec       5
# 2      Hotel Grad Otočec          Blaž Lusavec       5
# 3      Hotel Grad Otočec               Uros R.       5
# 4      Hotel Grad Otočec       Bogdan Tertinek       5
# ...                  ...                   ...     ...
# 2546  Oystermouth Castle             Kate Long       5
# 2547  Oystermouth Castle          Mia Thurgood       5
# 2548  Oystermouth Castle          Rohit Mishra       4
# 2549  Oystermouth Castle   Joseph Emman Pineda       4
# 2550  Oystermouth Castle  Miss Camille Bennett       5
#
#                                                  Review Sentiment   Latitude  \
# 0     More than a great and magical place. Clean, ta...  positive  45.838009
# 1     The Otočec castle, built on one of the islands...  positive  45.838009
# 2     Very tasty large cup of cappuccino and very go...  positive  45.838009
# 3     A beautiful castle to visit on an island on Kr...  positive  45.838009
# 4     This magnificent five-stars hotel hosts also a...  positive  45.838009
# ...                                                 ...       ...        ...
# 2546  Really interesting castle with a long and rich...  positive  51.576800
# 2547  Very nice castle, prices were good and family ...  positive  51.576800
# 2548  A perfect visit on a sunny day. It's a old cas...  positive  51.576800
# 2549  This is definitely worth a stop if you're visi...  positive  51.576800
# 2550  We didn't manage to go inside because it was s...  positive  51.576800
#
#       Longitude Adminstrative_Area_Level_1 Adminstrative_Area_Level_2  \
# 0     15.234847                        NaN                        NaN
# 1     15.234847                        NaN                        NaN
# 2     15.234847                        NaN                        NaN
# 3     15.234847                        NaN                        NaN
# 4     15.234847                        NaN                        NaN
# ...         ...                        ...                        ...
# 2546  -4.002459                    Mumbles                    Swansea
# 2547  -4.002459                    Mumbles                    Swansea
# 2548  -4.002459                    Mumbles                    Swansea
# 2549  -4.002459                    Mumbles                    Swansea
# 2550  -4.002459                    Mumbles                    Swansea
#
#      Municipality         Country Postal_Code  \
# 0      Novo mesto        Slovenia        8222
# 1      Novo mesto        Slovenia        8222
# 2      Novo mesto        Slovenia        8222
# 3      Novo mesto        Slovenia        8222
# 4      Novo mesto        Slovenia        8222
# ...           ...             ...         ...
# 2546        Wales  United Kingdom      SA34BA
# 2547        Wales  United Kingdom      SA34BA
# 2548        Wales  United Kingdom      SA34BA
# 2549        Wales  United Kingdom      SA34BA
# 2550        Wales  United Kingdom      SA34BA
#
#                                        Address  \
# 0       Grajska cesta 2, 8222 Otočec, Slovenia
# 1       Grajska cesta 2, 8222 Otočec, Slovenia
# 2       Grajska cesta 2, 8222 Otočec, Slovenia
# 3       Grajska cesta 2, 8222 Otočec, Slovenia
# 4       Grajska cesta 2, 8222 Otočec, Slovenia
# ...                                        ...
# 2546  Castle Ave, Mumbles, Swansea SA3 4BA, UK
# 2547  Castle Ave, Mumbles, Swansea SA3 4BA, UK
# 2548  Castle Ave, Mumbles, Swansea SA3 4BA, UK
# 2549  Castle Ave, Mumbles, Swansea SA3 4BA, UK
# 2550  Castle Ave, Mumbles, Swansea SA3 4BA, UK
#
#                                       Editorial_Summary  \
# 0     Refined hotel in a medieval castle offering a ...
# 1     Refined hotel in a medieval castle offering a ...
# 2     Refined hotel in a medieval castle offering a ...
# 3     Refined hotel in a medieval castle offering a ...
# 4     Refined hotel in a medieval castle offering a ...
# ...                                                 ...
# 2546  Remains of a castle in use from 1106 to around...
# 2547  Remains of a castle in use from 1106 to around...
# 2548  Remains of a castle in use from 1106 to around...
# 2549  Remains of a castle in use from 1106 to around...
# 2550  Remains of a castle in use from 1106 to around...
#
#                                              Open_Hours  User_Rating  \
# 0                                                   NaN       1847.0
# 1                                                   NaN       1847.0
# 2                                                   NaN       1847.0
# 3                                                   NaN       1847.0
# 4                                                   NaN       1847.0
# ...                                                 ...          ...
# 2546  ['Monday: 1100 - 1700', 'Tuesday: 1100 - 1700'...        956.0
# 2547  ['Monday: 1100 - 1700', 'Tuesday: 1100 - 1700'...        956.0
# 2548  ['Monday: 1100 - 1700', 'Tuesday: 1100 - 1700'...        956.0
# 2549  ['Monday: 1100 - 1700', 'Tuesday: 1100 - 1700'...        956.0
# 2550  ['Monday: 1100 - 1700', 'Tuesday: 1100 - 1700'...        956.0
#
#      Wheelchair_Accessible_Entrance    Phone_Number  \
# 0                              True  (07) 384 89 01
# 1                              True  (07) 384 89 01
# 2                              True  (07) 384 89 01
# 3                              True  (07) 384 89 01
# 4                              True  (07) 384 89 01
# ...                             ...             ...
# 2546                           True             NaN
# 2547                           True             NaN
# 2548                           True             NaN
# 2549                           True             NaN
# 2550                           True             NaN
#
#      International_Phone_Number                                  Website
# 0              +386 7 384 89 01              http://www.grad-otocec.com/
# 1              +386 7 384 89 01              http://www.grad-otocec.com/
# 2              +386 7 384 89 01              http://www.grad-otocec.com/
# 3              +386 7 384 89 01              http://www.grad-otocec.com/
# 4              +386 7 384 89 01              http://www.grad-otocec.com/
# ...                         ...                                      ...
# 2546                        NaN  http://swansea.gov.uk/oystermouthcastle
# 2547                        NaN  http://swansea.gov.uk/oystermouthcastle
# 2548                        NaN  http://swansea.gov.uk/oystermouthcastle
# 2549                        NaN  http://swansea.gov.uk/oystermouthcastle
# 2550                        NaN  http://swansea.gov.uk/oystermouthcastle
#
# [2551 rows x 20 columns]

# %%
top_countries = df_joined["Country"].value_counts().head(10).index

counts_top = (
    df_joined[df_joined["Country"].isin(top_countries)]
    .groupby(["Country", "Sentiment"])
    .size()
    .reset_index(name="count")
)

plt.figure(figsize=(12, 6))

sns.barplot(
    data=counts_top,
    x="Country",
    y="count",
    hue="Sentiment"
)

plt.title("Top 10 Countries: Positive vs Negative Reviews")
plt.xlabel("Country")
plt.ylabel("Number of Reviews")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
df_joined['tokens'] = df_joined['Review'].apply(
    lambda x: word_tokenize(x.lower())
)
df_joined
# Out:
#                     Name                Author  Rating  \
# 0      Hotel Grad Otočec         Ivet Sotirova       4
# 1      Hotel Grad Otočec    Gordana Podvezanec       5
# 2      Hotel Grad Otočec          Blaž Lusavec       5
# 3      Hotel Grad Otočec               Uros R.       5
# 4      Hotel Grad Otočec       Bogdan Tertinek       5
# ...                  ...                   ...     ...
# 2546  Oystermouth Castle             Kate Long       5
# 2547  Oystermouth Castle          Mia Thurgood       5
# 2548  Oystermouth Castle          Rohit Mishra       4
# 2549  Oystermouth Castle   Joseph Emman Pineda       4
# 2550  Oystermouth Castle  Miss Camille Bennett       5
#
#                                                  Review Sentiment   Latitude  \
# 0     More than a great and magical place. Clean, ta...  positive  45.838009
# 1     The Otočec castle, built on one of the islands...  positive  45.838009
# 2     Very tasty large cup of cappuccino and very go...  positive  45.838009
# 3     A beautiful castle to visit on an island on Kr...  positive  45.838009
# 4     This magnificent five-stars hotel hosts also a...  positive  45.838009
# ...                                                 ...       ...        ...
# 2546  Really interesting castle with a long and rich...  positive  51.576800
# 2547  Very nice castle, prices were good and family ...  positive  51.576800
# 2548  A perfect visit on a sunny day. It's a old cas...  positive  51.576800
# 2549  This is definitely worth a stop if you're visi...  positive  51.576800
# 2550  We didn't manage to go inside because it was s...  positive  51.576800
#
#       Longitude Adminstrative_Area_Level_1 Adminstrative_Area_Level_2  \
# 0     15.234847                        NaN                        NaN
# 1     15.234847                        NaN                        NaN
# 2     15.234847                        NaN                        NaN
# 3     15.234847                        NaN                        NaN
# 4     15.234847                        NaN                        NaN
# ...         ...                        ...                        ...
# 2546  -4.002459                    Mumbles                    Swansea
# 2547  -4.002459                    Mumbles                    Swansea
# 2548  -4.002459                    Mumbles                    Swansea
# 2549  -4.002459                    Mumbles                    Swansea
# 2550  -4.002459                    Mumbles                    Swansea
#
#      Municipality  ... Postal_Code                                   Address  \
# 0      Novo mesto  ...        8222    Grajska cesta 2, 8222 Otočec, Slovenia
# 1      Novo mesto  ...        8222    Grajska cesta 2, 8222 Otočec, Slovenia
# 2      Novo mesto  ...        8222    Grajska cesta 2, 8222 Otočec, Slovenia
# 3      Novo mesto  ...        8222    Grajska cesta 2, 8222 Otočec, Slovenia
# 4      Novo mesto  ...        8222    Grajska cesta 2, 8222 Otočec, Slovenia
# ...           ...  ...         ...                                       ...
# 2546        Wales  ...      SA34BA  Castle Ave, Mumbles, Swansea SA3 4BA, UK
# 2547        Wales  ...      SA34BA  Castle Ave, Mumbles, Swansea SA3 4BA, UK
# 2548        Wales  ...      SA34BA  Castle Ave, Mumbles, Swansea SA3 4BA, UK
# 2549        Wales  ...      SA34BA  Castle Ave, Mumbles, Swansea SA3 4BA, UK
# 2550        Wales  ...      SA34BA  Castle Ave, Mumbles, Swansea SA3 4BA, UK
#
#                                       Editorial_Summary  \
# 0     Refined hotel in a medieval castle offering a ...
# 1     Refined hotel in a medieval castle offering a ...
# 2     Refined hotel in a medieval castle offering a ...
# 3     Refined hotel in a medieval castle offering a ...
# 4     Refined hotel in a medieval castle offering a ...
# ...                                                 ...
# 2546  Remains of a castle in use from 1106 to around...
# 2547  Remains of a castle in use from 1106 to around...
# 2548  Remains of a castle in use from 1106 to around...
# 2549  Remains of a castle in use from 1106 to around...
# 2550  Remains of a castle in use from 1106 to around...
#
#                                              Open_Hours User_Rating  \
# 0                                                   NaN      1847.0
# 1                                                   NaN      1847.0
# 2                                                   NaN      1847.0
# 3                                                   NaN      1847.0
# 4                                                   NaN      1847.0
# ...                                                 ...         ...
# 2546  ['Monday: 1100 - 1700', 'Tuesday: 1100 - 1700'...       956.0
# 2547  ['Monday: 1100 - 1700', 'Tuesday: 1100 - 1700'...       956.0
# 2548  ['Monday: 1100 - 1700', 'Tuesday: 1100 - 1700'...       956.0
# 2549  ['Monday: 1100 - 1700', 'Tuesday: 1100 - 1700'...       956.0
# 2550  ['Monday: 1100 - 1700', 'Tuesday: 1100 - 1700'...       956.0
#
#       Wheelchair_Accessible_Entrance    Phone_Number  \
# 0                               True  (07) 384 89 01
# 1                               True  (07) 384 89 01
# 2                               True  (07) 384 89 01
# 3                               True  (07) 384 89 01
# 4                               True  (07) 384 89 01
# ...                              ...             ...
# 2546                            True             NaN
# 2547                            True             NaN
# 2548                            True             NaN
# 2549                            True             NaN
# 2550                            True             NaN
#
#      International_Phone_Number                                  Website  \
# 0              +386 7 384 89 01              http://www.grad-otocec.com/
# 1              +386 7 384 89 01              http://www.grad-otocec.com/
# 2              +386 7 384 89 01              http://www.grad-otocec.com/
# 3              +386 7 384 89 01              http://www.grad-otocec.com/
# 4              +386 7 384 89 01              http://www.grad-otocec.com/
# ...                         ...                                      ...
# 2546                        NaN  http://swansea.gov.uk/oystermouthcastle
# 2547                        NaN  http://swansea.gov.uk/oystermouthcastle
# 2548                        NaN  http://swansea.gov.uk/oystermouthcastle
# 2549                        NaN  http://swansea.gov.uk/oystermouthcastle
# 2550                        NaN  http://swansea.gov.uk/oystermouthcastle
#
#                                                  tokens
# 0     [more, than, a, great, and, magical, place, .,...
# 1     [the, otočec, castle, ,, built, on, one, of, t...
# 2     [very, tasty, large, cup, of, cappuccino, and,...
# 3     [a, beautiful, castle, to, visit, on, an, isla...
# 4     [this, magnificent, five-stars, hotel, hosts, ...
# ...                                                 ...
# 2546  [really, interesting, castle, with, a, long, a...
# 2547  [very, nice, castle, ,, prices, were, good, an...
# 2548  [a, perfect, visit, on, a, sunny, day, ., it, ...
# 2549  [this, is, definitely, worth, a, stop, if, you...
# 2550  [we, did, n't, manage, to, go, inside, because...
#
# [2551 rows x 21 columns]

# %% [markdown]
# Before stopword removal

# %%
# Number of tokens before deleting stopwords
total_tokens = df_joined['tokens'].apply(len).sum()
total_tokens
# Out:
# 158541

# %%
negations = {"not", "no", "never", "n't", "cannot", "don't", "won't", "isn't", "wasn't", "aren't"}

# %%
# Determining the stopwords to be deleted
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Remove negations from stopwords
stop_words = stop_words - negations
print(f"Default Stopwords: {len(stop_words)} words")
# Out:
# Default Stopwords: 191 words
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lukasz\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
custom_stopwords = {'castle', 'hotel', 'property', 'room', 'holiday', 'vacation', 'visit', 'location', 'town', 'place', 'ruin', 'ruins'}

# %%
extended_stopwords = stop_words.union(custom_stopwords)
print(f"Extended Stopwords: {len(extended_stopwords)} words")
# Out:
# Extended Stopwords: 203 words

# %%
punctuation = set(string.punctuation)

# %%
df_joined["filtered_tokens"] = df_joined["tokens"].apply(
    lambda tokens: [word for word in tokens if word not in extended_stopwords and word not in punctuation]
)

# %% [markdown]
# After stopword removal

# %%
tokens_minus_stopwords = df_joined['filtered_tokens'].apply(len).sum()
tokens_minus_stopwords
# Out:
# 71329

# %%
df_joined["filtered_tokens"]
# Out:
# 0       [great, magical, clean, tasty, unique, walks, ...
# 1       [otočec, built, one, islands, krka, river, slo...
# 2       [tasty, large, cup, cappuccino, good, fresh, i...
# 3       [beautiful, island, krka, river, see, details,...
# 4       [magnificent, five-stars, hosts, also, micheli...
#                               ...
# 2546    [really, interesting, long, rich, history, vol...
# 2547    [nice, prices, good, family, tickets, availabl...
# 2548    [perfect, sunny, day, 's, old, not, good, shap...
# 2549    [definitely, worth, stop, 're, visiting, wales...
# 2550    [n't, manage, go, inside, shut, disappointing,...
# Name: filtered_tokens, Length: 2551, dtype: object

# %% [markdown]
# # 1) AFINN

# %%
afinn = Afinn()

# %%
def afinn_sentiment(tokens):
    if not tokens:
        return 0
    return sum(afinn.score(word) for word in tokens)

df_joined["afinn_score"] = df_joined["filtered_tokens"].apply(afinn_sentiment)

# %%
print(df_joined['afinn_score'].notnull().sum())
print(len(df_joined))
# Out:
# 2551
# 2551

# %%
def afinn_label(score):
    if score > 0:
        return "positive"
    elif score <= 0:
        return "negative"

df_joined["afinn_sentiment"] = df_joined["afinn_score"].apply(afinn_label)

# %%
# Flatten tokens with sentiment filtering
sentiment_value = "positive" 

# Filter dataframe
df_filtered = df_joined[df_joined["afinn_sentiment"] == sentiment_value]

# Flatten list of tokens
all_tokens = [token for tokens in df_filtered["filtered_tokens"] for token in tokens]

# Count occurrences
token_counts = Counter(all_tokens)

# Map tokens to AFINN scores
from afinn import Afinn
afinn = Afinn()

# Build table
data = []
for token, count in token_counts.items():
    value = afinn.score(token)
    data.append({"word": token, "value": value, "n": count})

df_word_table = pd.DataFrame(data)

# Sort by frequency descending
df_word_table = df_word_table.sort_values(by="n", ascending=False).reset_index(drop=True)

# Show top 20 words
print(df_word_table.head(20))
# Out:
#          word  value    n
# 0   beautiful    3.0  816
# 1         not    0.0  700
# 2        nice    3.0  661
# 3       great    3.0  652
# 4          's    0.0  534
# 5        well    0.0  526
# 6       worth    2.0  493
# 7       views    0.0  490
# 8        walk    0.0  461
# 9      around    0.0  436
# 10          ’    0.0  431
# 11    history    0.0  429
# 12       also    0.0  405
# 13        see    0.0  404
# 14       tour    0.0  400
# 15       good    3.0  396
# 16    amazing    4.0  387
# 17       time    0.0  350
# 18        n't    0.0  344
# 19        one    0.0  336

# %% [markdown]
# By looking at the 20 most common tokens we can see that there is still some cleaning to be done. Especially instances such as punctuation `'` that was not removed, possessive contractions `'s` as well as negation contraction `n't`. Moreover, vast majority of words are also what can be treated as custom stopwords in this example. Words such as `views`, `walk` or `tour` appear very often among the reviews, however they do not carry any sentiment.

# %%
candidate_stopwords = df_word_table[
    (df_word_table["value"] == 0) &   # no sentiment
    (df_word_table["n"] > 150)  
]["word"].tolist()

candidate_stopwords[:30]
# Out:
# ['not',
#  "'s",
#  'well',
#  'views',
#  'walk',
#  'around',
#  '’',
#  'history',
#  'also',
#  'see',
#  'tour',
#  'time',
#  "n't",
#  'one',
#  'inside',
#  'view',
#  'really',
#  'parking',
#  'day',
#  'gardens',
#  'get',
#  'take',
#  'would',
#  'small',
#  'go',
#  'park',
#  'rooms',
#  'lot',
#  'guide',
#  'palace']

# %%
late_punct = set(string.punctuation) | {"’", "‘"}
late_noise = {"'s", "n't"}
custom_stopwords = set(candidate_stopwords)

final_stopwords = late_punct | late_noise | custom_stopwords

# %%
df_joined["filtered_tokens_clean"] = df_joined["filtered_tokens"].apply(
    lambda tokens: [
        w for w in tokens
        if w not in final_stopwords
        and w.isalpha()
    ]
)

# %%
sentiment_value = "positive"

df_filtered = df_joined[df_joined["afinn_sentiment"] == sentiment_value]

# Flatten list of tokens
all_tokens = [token for tokens in df_filtered["filtered_tokens_clean"] for token in tokens]

token_counts = Counter(all_tokens)

# Map tokens to AFINN scores
afinn = Afinn()

data = []
for token, count in token_counts.items():
    value = afinn.score(token)
    data.append({"word": token, "value": value, "n": count})

df_word_table = pd.DataFrame(data)

df_word_table = df_word_table.sort_values(by="n", ascending=False).reset_index(drop=True)

print(df_word_table.head(20))
# Out:
#            word  value    n
# 0     beautiful    3.0  816
# 1          nice    3.0  661
# 2         great    3.0  652
# 3         worth    2.0  493
# 4          good    3.0  396
# 5       amazing    4.0  387
# 6   interesting    2.0  326
# 7        lovely    3.0  261
# 8     recommend    2.0  259
# 9          free    1.0  253
# 10          top    2.0  230
# 11         like    2.0  211
# 12           no   -1.0  161
# 13     stunning    4.0  153
# 14      outside    0.0  150
# 15    wonderful    4.0  150
# 16     friendly    2.0  147
# 17       ticket    0.0  146
# 18         must    0.0  144
# 19        quite    0.0  142

# %%
# Compute AFINN score for each token
token_scores = [afinn.score(w) for w in all_tokens]
df_token_scores = pd.DataFrame({"value": token_scores})

# Filter out neutral tokens
df_token_scores = df_token_scores[df_token_scores["value"] != 0]

# Count distribution
token_sentiment_dist = (
    df_token_scores["value"]
    .value_counts()
    .sort_index()
    .reset_index()
)

token_sentiment_dist.columns = ["value", "n"]

token_sentiment_dist
# Out:
#    value     n
# 0   -4.0     5
# 1   -3.0   104
# 2   -2.0   513
# 3   -1.0   589
# 4    1.0  1409
# 5    2.0  3413
# 6    3.0  4056
# 7    4.0  1022
# 8    5.0   100

# %%
token_data = []

for tokens in df_joined["filtered_tokens_clean"]:
    for w in tokens:
        score = afinn.score(w)
        if score != 0:  # ignore neutral
            token_data.append({"word": w, "value": score})

df_tokens = pd.DataFrame(token_data)

# Count frequency of each word per sentiment value
df_counts = (
    df_tokens.groupby(["value", "word"])
    .size()
    .reset_index(name="n")
)
top_words = (
    df_counts.groupby("value")
    .apply(lambda x: x.nlargest(5, "n"))
    .reset_index(drop=True)
)

g = sns.FacetGrid(top_words, col="value", col_wrap=3, sharex=False, sharey=False, height=3)
g.map_dataframe(
    sns.barplot,
    x="word",
    y="n",
    palette="coolwarm"
)

for ax in g.axes.flat:
    ax.set_ylabel("Frequency")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right") 

g.fig.subplots_adjust(top=0.88, hspace=0.5)

g.fig.suptitle("Top 5 Words per Sentiment Value", fontsize=14)
plt.show()

# %%
df_joined['afinn_review_score'] = df_joined['filtered_tokens_clean'].apply(
    lambda tokens: sum(afinn.score(w) for w in tokens)
)

# %%
# Plot histogram
plt.figure(figsize=(10,6))
sns.histplot(
    df_joined['afinn_review_score'],
    bins=30,
    color='skyblue',
    stat="density",
    edgecolor='black'
)

sns.kdeplot(
    df_joined['afinn_review_score'],
    color='red', 
    linewidth=2
)

plt.title('Histogram of Review-Level AFINN Sentiment Scores', fontsize=14)
plt.xlabel('AFINN Review Score')
plt.ylabel('Density')
plt.grid(alpha=0.3)
plt.show()

# %%
# Boxplot sentiment score vs. star rating
plt.figure(figsize=(10,6))
sns.boxplot(
    x='Rating',  
    y='afinn_review_score',
    data=df_joined,
    palette='pastel'
)

plt.title('Distribution of AFINN Review Scores per Star Rating', fontsize=14)
plt.xlabel('Star Rating')
plt.ylabel('AFINN Review Score')
plt.grid(alpha=0.3, axis='y')
plt.show()

# %%
df_joined["tokens_for_bigrams"] = df_joined["Review"].str.lower().str.split().apply(
    lambda tokens: [w for w in tokens if w.isalpha() and w not in stop_words]
)
df_joined["bigrams"] = df_joined["tokens_for_bigrams"].apply(lambda x: list(bigrams(x)))

# %%
df_bigrams = pd.DataFrame(
    [bg for row in df_joined["bigrams"] for bg in row],
    columns=["word1", "word2"]
)

# %%
negated_bigrams = df_bigrams[df_bigrams["word1"].isin(negations)].copy()

# %%
negated_bigrams["value"] = negated_bigrams["word2"].apply(afinn.score)

# %%
negated_bigrams["value"] = -negated_bigrams["value"]

negated_bigrams["sentiment"] = negated_bigrams["value"].apply(
    lambda x: "positive" if x > 0 else "negative"
)

# %%
negated_summary = (
    negated_bigrams
    .groupby(["word1", "word2", "sentiment"])
    .size()
    .reset_index(name="n")
    .sort_values("n", ascending=False)
)

negated_summary.head(20)
# Out:
#     word1       word2 sentiment   n
# 404   not        much  negative  32
# 206   not     allowed  negative  14
# 553   not       worth  negative  13
# 301   not         far  negative  13
# 234   not        busy  negative  11
# 508   not        sure  negative  11
# 135    no         one  negative  10
# 285   not        even  negative  10
# 202   not  accessible  negative  10
# 505   not    suitable  negative   8
# 272   not        easy  negative   8
# 459   not      really  negative   7
# 279   not      enough  negative   7
# 462   not   recommend  negative   7
# 326   not       great  negative   7
# 221   not         bad  positive   7
# 394   not        many  negative   7
# 325   not        good  negative   6
# 400   not        miss  positive   6
# 199   not        able  negative   6

# %% [markdown]
# REGULAR BIGRAMS

# %%
# Generate all bigrams
all_bigrams = [
    bg
    for tokens in df_joined["filtered_tokens_clean"]
    for bg in bigrams(tokens)
]

# Convert to DataFrame
df_bigrams = pd.DataFrame(all_bigrams, columns=["word1", "word2"])

# Count frequency
bigram_counts = (
    df_bigrams
    .value_counts()
    .reset_index(name="n")
    .sort_values("n", ascending=False)
)

bigram_counts.head(20)
# Out:
#          word1        word2   n
# 0       highly    recommend  66
# 1         gift         shop  54
# 2         make         sure  45
# 3       highly  recommended  36
# 4        worth     visiting  33
# 5          ice        cream  27
# 6       guided        tours  27
# 7          buy      tickets  23
# 8    recommend     visiting  23
# 9   absolutely    beautiful  21
# 10       years          ago  21
# 11         top         hill  20
# 12        free        entry  19
# 13      hidden          gem  19
# 14    friendly      helpful  17
# 18        feel         like  16
# 17       spend        hours  16
# 16       entry          fee  16
# 15         per       person  16
# 19       worth       seeing  15

# %%
bigram_counts["afinn_score"] = (
    bigram_counts["word1"].apply(afinn.score) +
    bigram_counts["word2"].apply(afinn.score)
)

# %%
top_positive_bigrams = (
    bigram_counts
    .query("afinn_score > 0")
    .sort_values("n", ascending=False)
    .head(20)
)

top_positive_bigrams
# Out:
#          word1        word2   n  afinn_score
# 0       highly    recommend  66          2.0
# 1         gift         shop  54          2.0
# 3       highly  recommended  36          2.0
# 4        worth     visiting  33          2.0
# 8    recommend     visiting  23          2.0
# 9   absolutely    beautiful  21          3.0
# 11         top         hill  20          2.0
# 12        free        entry  19          1.0
# 13      hidden          gem  19          3.0
# 14    friendly      helpful  17          4.0
# 18        feel         like  16          2.0
# 19       worth       seeing  15          2.0
# 20       looks         like  15          2.0
# 21       great          top  14          5.0
# 23   beautiful        great  14          6.0
# 28  absolutely      amazing  13          4.0
# 30       worth         trip  13          2.0
# 29    national        trust  13          1.0
# 25   beautiful  interesting  13          5.0
# 27      easily   accessible  13          1.0

# %%
top_negative_bigrams = (
    bigram_counts
    .query("afinn_score < 0")
    .sort_values("n", ascending=False)
    .head(20)
)

top_negative_bigrams
# Out:
#        word1          word2  n  afinn_score
# 80      need            pay  9         -1.0
# 179      bus           stop  6         -1.0
# 235    world            war  5         -2.0
# 230     must           stop  5         -1.0
# 394   almost             no  4         -1.0
# 447     sure            pay  4         -1.0
# 357     told             no  4         -1.0
# 342       wo         regret  4         -2.0
# 435      pay           card  4         -1.0
# 533   scared        heights  4         -2.0
# 527       no           cafe  4         -1.0
# 513      bit  disappointing  4         -2.0
# 483       no         crowds  4         -1.0
# 511      bit         boring  4         -3.0
# 904     sure           stop  3         -1.0
# 768    leave            tip  3         -1.0
# 841  tourist           trap  3         -1.0
# 803      war       memorial  3         -2.0
# 815      war             ii  3         -2.0
# 811  torture        chamber  3         -4.0

# %% [markdown]
# # VADER

# %%
vader = SentimentIntensityAnalyzer()

# %%
# Compute VADER scores
df_joined['vader_scores'] = df_joined['Review'].apply(vader.polarity_scores)

# Extract compound score
df_joined['vader_compound'] = df_joined['vader_scores'].apply(lambda x: x['compound'])

# %%
df_joined['vader_pos'] = df_joined['vader_scores'].apply(lambda x: x['pos'])
df_joined['vader_neg'] = df_joined['vader_scores'].apply(lambda x: x['neg'])

# %%
df_joined["vader_sentiment"] = np.where(
    df_joined["vader_compound"] > 0,  # treat neutral as negative
    "positive",
    "negative"
)

# Check distribution
df_joined["vader_sentiment"].value_counts()
# Out:
# vader_sentiment
# positive    2376
# negative     175
# Name: count, dtype: int64

# %%
# Plot histogram
plt.figure(figsize=(10,6))
sns.histplot(
    df_joined['vader_compound'],
    bins=30,
    color='lightgreen',
    stat="density",
    edgecolor='black'
)

sns.kdeplot(
    df_joined['vader_compound'],
    color='red',   
    linewidth=2
)

plt.title('Histogram of Review-Level VADER Sentiment Scores', fontsize=14)
plt.xlabel('VADER Compound Score')
plt.ylabel('Density')
plt.grid(alpha=0.3)
plt.show()

# %%
# Boxplot VADER sentiment score vs. star rating
plt.figure(figsize=(10,6))
sns.boxplot(
    x='Rating',  
    y='vader_compound',
    data=df_joined,
    palette='pastel'
)

plt.title('Distribution of VADER Compound Scores per Star Rating', fontsize=14)
plt.xlabel('Star Rating')
plt.ylabel('VADER Compound Score')
plt.grid(alpha=0.3, axis='y')
plt.show()

# %%
df_bigrams["vader_compound"] = df_bigrams["word2"].apply(
    lambda w: vader.polarity_scores(w)["compound"]
)

# %%
df_bigrams = df_bigrams[df_bigrams["vader_compound"] != 0]

# %%
bigram_summary_vader = (
    df_bigrams
    .groupby(["word1", "word2", "vader_compound"])
    .size()
    .reset_index(name="n")
)

# %%
top_positive_bigrams_vader = (
    bigram_summary_vader[bigram_summary_vader["vader_compound"] > 0]
    .sort_values("n", ascending=False)
    .head(20)
)
top_positive_bigrams_vader
# Out:
#            word1        word2  vader_compound   n
# 3635      highly    recommend          0.3612  66
# 4845        make         sure          0.3182  45
# 3636      highly  recommended          0.2023  36
# 21    absolutely    beautiful          0.5994  21
# 3053    friendly      helpful          0.4215  17
# 2814        feel         like          0.3612  16
# 4637       looks         like          0.3612  15
# 704    beautiful        great          0.6249  14
# 3420       great          top          0.2023  14
# 20    absolutely      amazing          0.5859  13
# 712    beautiful  interesting          0.4019  13
# 5205    national        trust          0.5106  13
# 39    absolutely     stunning          0.3818  12
# 721    beautiful         nice          0.4215  12
# 2083         dog     friendly          0.4939  12
# 7734       taken         care          0.4939  12
# 5350        nice         nice          0.4215  12
# 756    beautiful        worth          0.2263  11
# 5308        nice    beautiful          0.5994  11
# 5327        nice     friendly          0.4939  10

# %%
top_negative_bigrams_vader = (
    bigram_summary_vader[bigram_summary_vader["vader_compound"] < 0]
    .sort_values("n", ascending=False)
    .head(20)
)
top_negative_bigrams_vader
# Out:
#               word1          word2  vader_compound  n
# 5261           need            pay         -0.1027  9
# 1131            bus           stop         -0.2960  6
# 5183           must           stop         -0.2960  5
# 8893          world            war         -0.5994  5
# 238          almost             no         -0.2960  4
# 904             bit  disappointing         -0.4939  4
# 8928          worth           stop         -0.2960  4
# 7661           sure            pay         -0.1027  4
# 8010           told             no         -0.2960  4
# 8811             wo         regret         -0.4215  4
# 897             bit         boring         -0.3182  4
# 8808             wo   disappointed         -0.4767  3
# 3412          great           stop         -0.2960  3
# 8802        without          doubt         -0.3612  3
# 8368             us             no         -0.2960  3
# 471           armor        weapons         -0.4404  3
# 8312  unfortunately             no         -0.2960  3
# 2121       downside             no         -0.2960  3
# 7663           sure           stop         -0.2960  3
# 8899          worth          alone         -0.2500  3

# %% [markdown]
# # AFINN vs VADER

# %%
# normalize AFINn
afinn_scores = df_joined['afinn_review_score'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(-1,1))
df_joined['afinn_scaled'] = scaler.fit_transform(afinn_scores)

# Plot
sns.kdeplot(df_joined['afinn_scaled'], label='AFINN', fill=True)
sns.kdeplot(df_joined['vader_compound'], label='VADER', fill=True)
plt.title("Comparison of Review-Level Sentiment Scores with AFINN normalized")
plt.xlabel("Sentiment Score")
plt.legend()
plt.show()

# %%
df_joined["agreement"] = (
    df_joined["afinn_sentiment"] == df_joined["vader_sentiment"]
)

df_joined["agreement"].value_counts(normalize=True)
# Out:
# agreement
# True     0.957272
# False    0.042728
# Name: proportion, dtype: float64
